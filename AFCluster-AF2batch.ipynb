# %% [markdown]
# #ColabFold v1.5.2: AlphaFold2 w/ MMseqs2 BATCH
# ##Modified by Xiao L based on original [AF-Cluster](https://colab.research.google.com/github/HWaymentSteele/AF_Cluster/blob/main/AFcluster.ipynb) notebook
#
# <img src="https://raw.githubusercontent.com/sokrypton/ColabFold/main/.github/ColabFold_Marv_Logo_Small.png" height="256" align="right" style="height:256px">
#
# Easy to use AlphaFold2 protein structure [(Jumper et al. 2021)](https://www.nature.com/articles/s41586-021-03819-2) and complex [(Evans et al. 2021)](https://www.biorxiv.org/content/10.1101/2021.10.04.463034v1) prediction using multiple sequence alignments generated through MMseqs2. For details, refer to our manuscript:
#
# [Mirdita M, Schütze K, Moriwaki Y, Heo L, Ovchinnikov S, Steinegger M. ColabFold: Making protein folding accessible to all.
# *Nature Methods*, 2022](https://www.nature.com/articles/s41592-022-01488-1)
#
# **Usage**
#
# `input_dir` directory with only fasta files or MSAs stored in Google Drive. MSAs need to be A3M formatted and have an `.a3m` extention. For MSAs MMseqs2 will not be called.
#
# `result_dir` results will be written to the result directory in Google Drive
#
# Old versions: [v1.4](https://colab.research.google.com/github/sokrypton/ColabFold/blob/v1.4.0/batch/AlphaFold2_batch.ipynb), [v1.5.1](https://colab.research.google.com/github/sokrypton/ColabFold/blob/v1.5.1//batch/AlphaFold2_batch.ipynb)
#
# <strong>For more details, see <a href="#Instructions">bottom</a> of the notebook and checkout the [ColabFold GitHub](https://github.com/sokrypton/ColabFold). </strong>
#
# -----------
#
# ### News
# - <b><font color='green'>2023/06/12: New databases! UniRef30 updated to 2023_02 and PDB to 230517. We now use PDB100 instead of PDB70 (see notes in the [main](https://colabfold.com) notebook).</font></b>
# - <b><font color='green'>2023/06/12: We introduced a new default pairing strategy: Previously, for multimer predictions with more than 2 chains, we only pair if all sequences taxonomically match ("complete" pairing). The new default "greedy" strategy pairs any taxonomically matching subsets.</font></b>

# %%
#@title Cluster MSA
# %%bash
if [ ! -d AFcluster ];then
  git clone https://github.com/AkanoLoki/AF_cluster.git
fi
if [ ! -d output ]; then
  mkdir output
fi
pip -q install ml-collections dm-haiku biopython polyleven

python AF_cluster/scripts/ClusterMSA.py hCLIC1Dimer -i hCLIC1FLForceDimer_8dfaa.a3m -o subsampled_MSAs --n_mer 2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 61.1 MB/s eta 0:00:00
# hCLIC1Dimer
# 1411 seqs removed for containing more than 25% gaps, 1791 remaining
# eps	n_clusters	n_not_clustered
# 3.00	1	448
# 3.50	1	448
# 4.00	2	445
# 4.50	1	448
# 5.00	2	445
# 5.50	5	429
# 6.00	7	421
# 6.50	8	406
# 7.00	11	386
# 7.50	12	380
# 8.00	20	311
# 8.50	20	295
# 9.00	24	215
# 9.50	21	197
# 10.00	20	160
# 10.50	18	137
# 11.00	14	111
# 11.50	15	101
# 12.00	14	90
# 12.50	10	84
# 13.00	17	49
# 13.50	14	51
# 14.00	15	49
# 14.50	13	42
# 15.00	12	21
# 15.50	10	31
# 16.00	12	22
# 16.50	8	8
# 17.00	3	2
# 17.50	2	1
# 18.00	1	0
# Selected eps=9.00
# 1791 total seqs
# 82 clusters, 516 of 1791 not clustered (0.29)
# avg identity to query of unclustered: 0.37
# avg identity to query of clustered: 0.48
# writing 10 size-10 uniformly sampled clusters
# writing 10 size-100 uniformly sampled clusters
# wrote clustering data to subsampled_MSAs/hCLIC1Dimer_clustering_assignments.tsv
# wrote cluster metadata to subsampled_MSAs/hCLIC1Dimer_cluster_metadata.tsv
# Saved this output to hCLIC1Dimer.log

# %%
#@title Mount google drive (if using google drive files)
from google.colab import drive
drive.mount('/content/drive')
from sys import version_info
python_version = f"{version_info.major}.{version_info.minor}"
# Out:
# Mounted at /content/drive

# %%
#@title Input protein sequence, then hit `Runtime` -> `Run all`

input_dir = '/content/subsampled_MSAs' #@param {type:"string"}
result_dir = '/content/output' #@param {type:"string"}

# number of models to use
#@markdown ---
#@markdown ### Advanced settings
msa_mode = "MMseqs2 (UniRef+Environmental)" #@param ["MMseqs2 (UniRef+Environmental)", "MMseqs2 (UniRef only)","single_sequence","custom"]
model_type = "alphafold2_multimer_v3" #@param ["alphafold2","alphafold2_ptm","alphafold2_multimer_v1","alphafold2_multimer_v2","alphafold2_multimer_v3",]{type:"string"}
num_models = 1 #@param [1,2,3,4,5] {type:"raw"}
num_recycles = 3 #@param [1,3,6,12,24,48] {type:"raw"}
stop_at_score = 100 #@param {type:"string"}
#@markdown - early stop computing models once score > threshold (avg. plddt for "structures" and ptmscore for "complexes")
use_custom_msa = False
use_amber = False #@param {type:"boolean"}
use_templates = False #@param {type:"boolean"}
do_not_overwrite_results = True #@param {type:"boolean"}
zip_results = False #@param {type:"boolean"}

# %%
#@title Install dependencies
# %%bash -s $use_amber $use_templates $python_version

set -e

USE_AMBER=$1
USE_TEMPLATES=$2
PYTHON_VERSION=$3

if [ ! -f COLABFOLD_READY ]; then
  # install dependencies
  # We have to use "--no-warn-conflicts" because colab already has a lot preinstalled with requirements different to ours
  pip install -q --no-warn-conflicts "colabfold[alphafold-minus-jax] @ git+https://github.com/sokrypton/ColabFold" "tensorflow-cpu==2.11.0"
  pip uninstall -yq jax jaxlib
  pip install -q "jax[cuda]==0.3.25" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
  touch COLABFOLD_READY
fi

# Download params (~1min)
python -m colabfold.download

# setup conda
if [ ${USE_AMBER} == "True" ] || [ ${USE_TEMPLATES} == "True" ]; then
  if [ ! -f CONDA_READY ]; then
    wget -qnc https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
    bash Miniconda3-latest-Linux-x86_64.sh -bfp /usr/local 2>&1 1>/dev/null
    rm Miniconda3-latest-Linux-x86_64.sh
    conda config --set auto_update_conda false
    touch CONDA_READY
  fi
fi
# setup template search
if [ ${USE_TEMPLATES} == "True" ] && [ ! -f HH_READY ]; then
  conda install -y -q -c conda-forge -c bioconda kalign2=2.04 hhsuite=3.3.0 python="${PYTHON_VERSION}" 2>&1 1>/dev/null
  touch HH_READY
fi
# setup openmm for amber refinement
if [ ${USE_AMBER} == "True" ] && [ ! -f AMBER_READY ]; then
  conda install -y -q -c conda-forge openmm=7.7.0 python="${PYTHON_VERSION}" pdbfixer 2>&1 1>/dev/null
  touch AMBER_READY
fi
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.5/221.5 MB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 83.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 69.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 92.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 47.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.0/242.0 kB 28.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 102.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 63.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 MB 7.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.7 requires jax>=0.4.6, but you have jax 0.3.25 which is incompatible.
# flax 0.6.11 requires jax>=0.4.2, but you have jax 0.3.25 which is incompatible.
# orbax-checkpoint 0.2.6 requires jax>=0.4.9, but you have jax 0.3.25 which is incompatible.
# tensorflow 2.12.0 requires keras<2.13,>=2.12.0, but you have keras 2.11.0 which is incompatible.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# tensorflow 2.12.0 requires tensorboard<2.13,>=2.12, but you have tensorboard 2.11.2 which is incompatible.
# tensorflow 2.12.0 requires tensorflow-estimator<2.13,>=2.12.0, but you have tensorflow-estimator 2.11.0 which is incompatible.
# Downloading alphafold2 weights to /root/.cache/colabfold: 100%|██████████| 3.82G/3.82G [00:26<00:00, 153MB/s]
# Downloading alphafold2 weights to /root/.cache/colabfold: 100%|██████████| 3.47G/3.47G [00:19<00:00, 192MB/s]

# %%
#@title Run Prediction

import sys

from colabfold.batch import get_queries, run
from colabfold.download import default_data_dir
from colabfold.utils import setup_logging
from pathlib import Path

# For some reason we need that to get pdbfixer to import
if use_amber and f"/usr/local/lib/python{python_version}/site-packages/" not in sys.path:
    sys.path.insert(0, f"/usr/local/lib/python{python_version}/site-packages/")

if 'logging_setup' not in globals():
    setup_logging(Path(result_dir).joinpath("log.txt"))
    logging_setup = True

queries, is_complex = get_queries(input_dir)
run(
    queries=queries,
    result_dir=result_dir,
    use_templates=use_templates,
    use_amber=use_amber,
    msa_mode=msa_mode,
    model_type=model_type,
    num_models=num_models,
    num_recycles=num_recycles,
    model_order=[1, 2, 3, 4, 5],
    is_complex=is_complex,
    data_dir=default_data_dir,
    keep_existing_results=do_not_overwrite_results,
    rank_by="auto",
    pair_mode="unpaired+paired",
    stop_at_score=stop_at_score,
    zip_results=zip_results,
)
# Out:
# 2023-06-30 19:58:05,019 non-fasta/a3m file in input directory: /content/subsampled_MSAs/hCLIC1Dimer_cluster_metadata.tsv
# 2023-06-30 19:58:05,023 non-fasta/a3m file in input directory: /content/subsampled_MSAs/hCLIC1Dimer_clustering_assignments.tsv
# 2023-06-30 19:58:09,740 Running on GPU
# 2023-06-30 19:58:09,888 Found 4 citations for tools or databases
# 2023-06-30 19:58:09,889 Query 1/102: hCLIC1Dimer_000 (length 241)
# 2023-06-30 19:59:21,410 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=39.3 pTM=0.235
# 2023-06-30 19:59:38,774 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=43.8 pTM=0.319 tol=7.4
# 2023-06-30 19:59:56,482 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=47.8 pTM=0.391 tol=11.5
# 2023-06-30 20:00:14,445 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=47 pTM=0.363 tol=1.93
# 2023-06-30 20:00:14,447 alphafold2_multimer_v3_model_1_seed_000 took 111.6s (3 recycles)
# 2023-06-30 20:00:14,527 reranking models by 'plddt' metric
# 2023-06-30 20:00:14,527 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=47 pTM=0.363
# 2023-06-30 20:00:16,253 Query 2/102: hCLIC1Dimer_001 (length 241)
# 2023-06-30 20:00:34,605 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=46 pTM=0.278
# 2023-06-30 20:00:53,128 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=45.3 pTM=0.263 tol=8.41
# 2023-06-30 20:01:11,961 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=49.6 pTM=0.279 tol=11
# 2023-06-30 20:01:31,092 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=56.5 pTM=0.42 tol=8.1
# 2023-06-30 20:01:31,093 alphafold2_multimer_v3_model_1_seed_000 took 74.8s (3 recycles)
# 2023-06-30 20:01:31,248 reranking models by 'plddt' metric
# 2023-06-30 20:01:31,249 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=56.5 pTM=0.42
# 2023-06-30 20:01:32,482 Query 3/102: hCLIC1Dimer_002 (length 241)
# 2023-06-30 20:01:51,889 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=54.2 pTM=0.396
# 2023-06-30 20:02:11,281 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=65.4 pTM=0.438 tol=8.45
# 2023-06-30 20:02:30,588 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=74.9 pTM=0.588 tol=7.71
# 2023-06-30 20:02:49,803 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=78.1 pTM=0.614 tol=0.756
# 2023-06-30 20:02:49,804 alphafold2_multimer_v3_model_1_seed_000 took 77.3s (3 recycles)
# 2023-06-30 20:02:49,945 reranking models by 'plddt' metric
# 2023-06-30 20:02:49,946 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=78.1 pTM=0.614
# 2023-06-30 20:02:51,863 Query 4/102: hCLIC1Dimer_003 (length 241)
# 2023-06-30 20:03:11,316 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=64.8 pTM=0.592
# 2023-06-30 20:03:31,048 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=88.4 pTM=0.809 tol=2.53
# 2023-06-30 20:03:50,530 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=93.3 pTM=0.857 tol=0.797
# 2023-06-30 20:04:09,889 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=94.7 pTM=0.875 tol=0.778
# 2023-06-30 20:04:09,890 alphafold2_multimer_v3_model_1_seed_000 took 78.0s (3 recycles)
# 2023-06-30 20:04:09,978 reranking models by 'plddt' metric
# 2023-06-30 20:04:09,979 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=94.7 pTM=0.875
# 2023-06-30 20:04:11,066 Query 5/102: hCLIC1Dimer_004 (length 241)
# 2023-06-30 20:04:30,369 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=58.8 pTM=0.544
# 2023-06-30 20:04:49,734 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=59.8 pTM=0.53 tol=3.62
# 2023-06-30 20:05:09,122 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=61.5 pTM=0.528 tol=2.05
# 2023-06-30 20:05:28,417 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=65.2 pTM=0.568 tol=1.29
# 2023-06-30 20:05:28,419 alphafold2_multimer_v3_model_1_seed_000 took 77.3s (3 recycles)
# 2023-06-30 20:05:28,500 reranking models by 'plddt' metric
# 2023-06-30 20:05:28,500 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=65.2 pTM=0.568
# 2023-06-30 20:05:29,894 Query 6/102: hCLIC1Dimer_005 (length 241)
# 2023-06-30 20:05:49,107 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=42.7 pTM=0.289
# 2023-06-30 20:06:08,258 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=42.9 pTM=0.288 tol=6.79
# 2023-06-30 20:06:27,394 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=44.2 pTM=0.293 tol=3.81
# 2023-06-30 20:06:46,443 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=46.8 pTM=0.34 tol=3.82
# 2023-06-30 20:06:46,445 alphafold2_multimer_v3_model_1_seed_000 took 76.5s (3 recycles)
# 2023-06-30 20:06:46,528 reranking models by 'plddt' metric
# 2023-06-30 20:06:46,529 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=46.8 pTM=0.34
# 2023-06-30 20:06:47,635 Query 7/102: hCLIC1Dimer_006 (length 241)
# 2023-06-30 20:07:06,657 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=43.5 pTM=0.331
# 2023-06-30 20:07:25,658 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=58.4 pTM=0.536 tol=5.81
# 2023-06-30 20:07:44,654 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=57.7 pTM=0.52 tol=2.94
# 2023-06-30 20:08:03,631 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=60.2 pTM=0.532 tol=1.45
# 2023-06-30 20:08:03,632 alphafold2_multimer_v3_model_1_seed_000 took 76.0s (3 recycles)
# 2023-06-30 20:08:03,714 reranking models by 'plddt' metric
# 2023-06-30 20:08:03,714 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=60.2 pTM=0.532
# 2023-06-30 20:08:04,803 Query 8/102: hCLIC1Dimer_007 (length 241)
# 2023-06-30 20:08:23,731 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=45.5 pTM=0.257
# 2023-06-30 20:08:42,664 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=52.1 pTM=0.295 tol=10.5
# 2023-06-30 20:09:01,622 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=52 pTM=0.274 tol=2.54
# 2023-06-30 20:09:20,575 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=51.7 pTM=0.272 tol=2.43
# 2023-06-30 20:09:20,576 alphafold2_multimer_v3_model_1_seed_000 took 75.8s (3 recycles)
# 2023-06-30 20:09:20,723 reranking models by 'plddt' metric
# 2023-06-30 20:09:20,724 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=51.7 pTM=0.272
# 2023-06-30 20:09:22,470 Query 9/102: hCLIC1Dimer_008 (length 241)
# 2023-06-30 20:09:41,483 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=45 pTM=0.289
# 2023-06-30 20:10:00,382 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=53 pTM=0.361 tol=10.1
# 2023-06-30 20:10:19,296 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=52.9 pTM=0.319 tol=8.17
# 2023-06-30 20:10:38,178 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=62 pTM=0.421 tol=7.18
# 2023-06-30 20:10:38,179 alphafold2_multimer_v3_model_1_seed_000 took 75.7s (3 recycles)
# 2023-06-30 20:10:38,263 reranking models by 'plddt' metric
# 2023-06-30 20:10:38,263 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=62 pTM=0.421
# 2023-06-30 20:10:39,381 Query 10/102: hCLIC1Dimer_009 (length 241)
# 2023-06-30 20:10:58,345 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=54 pTM=0.401
# 2023-06-30 20:11:17,316 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=81.1 pTM=0.712 tol=9.4
# 2023-06-30 20:11:36,311 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=88.6 pTM=0.819 tol=1.37
# 2023-06-30 20:11:55,280 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=93.1 pTM=0.864 tol=0.713
# 2023-06-30 20:11:55,281 alphafold2_multimer_v3_model_1_seed_000 took 75.9s (3 recycles)
# 2023-06-30 20:11:55,364 reranking models by 'plddt' metric
# 2023-06-30 20:11:55,364 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=93.1 pTM=0.864
# 2023-06-30 20:11:56,698 Query 11/102: hCLIC1Dimer_010 (length 241)
# 2023-06-30 20:12:15,682 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=58.5 pTM=0.521
# 2023-06-30 20:12:34,669 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=74.1 pTM=0.674 tol=5.95
# 2023-06-30 20:12:53,709 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=85.3 pTM=0.792 tol=2.81
# 2023-06-30 20:13:12,723 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=87.9 pTM=0.801 tol=0.346
# 2023-06-30 20:13:12,725 alphafold2_multimer_v3_model_1_seed_000 took 76.0s (3 recycles)
# 2023-06-30 20:13:12,868 reranking models by 'plddt' metric
# 2023-06-30 20:13:12,869 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=87.9 pTM=0.801
# 2023-06-30 20:13:14,581 Query 12/102: hCLIC1Dimer_011 (length 241)
# 2023-06-30 20:13:33,679 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=41.3 pTM=0.268
# 2023-06-30 20:13:52,682 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=62.2 pTM=0.465 tol=7.61
# 2023-06-30 20:14:11,771 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=73.3 pTM=0.629 tol=4.88
# 2023-06-30 20:14:30,790 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=79.6 pTM=0.68 tol=0.952
# 2023-06-30 20:14:30,791 alphafold2_multimer_v3_model_1_seed_000 took 76.2s (3 recycles)
# 2023-06-30 20:14:30,872 reranking models by 'plddt' metric
# 2023-06-30 20:14:30,872 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=79.6 pTM=0.68
# 2023-06-30 20:14:31,962 Query 13/102: hCLIC1Dimer_012 (length 241)
# 2023-06-30 20:14:50,837 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=42.1 pTM=0.274
# 2023-06-30 20:15:09,711 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=46.8 pTM=0.305 tol=8.59
# 2023-06-30 20:15:28,668 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=47.6 pTM=0.3 tol=5.42
# 2023-06-30 20:15:47,621 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=58.7 pTM=0.493 tol=5.9
# 2023-06-30 20:15:47,622 alphafold2_multimer_v3_model_1_seed_000 took 75.7s (3 recycles)
# 2023-06-30 20:15:47,780 reranking models by 'plddt' metric
# 2023-06-30 20:15:47,781 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=58.7 pTM=0.493
# 2023-06-30 20:15:49,429 Query 14/102: hCLIC1Dimer_013 (length 241)
# 2023-06-30 20:16:08,443 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=41.6 pTM=0.237
# 2023-06-30 20:16:27,373 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=51.9 pTM=0.384 tol=10.9
# 2023-06-30 20:16:46,279 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=59.9 pTM=0.465 tol=3.4
# 2023-06-30 20:17:05,229 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=62.2 pTM=0.492 tol=2.34
# 2023-06-30 20:17:05,230 alphafold2_multimer_v3_model_1_seed_000 took 75.8s (3 recycles)
# 2023-06-30 20:17:05,395 reranking models by 'plddt' metric
# 2023-06-30 20:17:05,396 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=62.2 pTM=0.492
# 2023-06-30 20:17:07,019 Query 15/102: hCLIC1Dimer_014 (length 241)
# 2023-06-30 20:17:25,957 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=47.6 pTM=0.318
# 2023-06-30 20:17:44,810 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=45.8 pTM=0.289 tol=4.17
# 2023-06-30 20:18:03,707 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=47 pTM=0.278 tol=2.9
# 2023-06-30 20:18:22,587 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=49.4 pTM=0.274 tol=4.79
# 2023-06-30 20:18:22,588 alphafold2_multimer_v3_model_1_seed_000 took 75.6s (3 recycles)
# 2023-06-30 20:18:22,669 reranking models by 'plddt' metric
# 2023-06-30 20:18:22,669 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=49.4 pTM=0.274
# 2023-06-30 20:18:24,103 Query 16/102: hCLIC1Dimer_015 (length 241)
# 2023-06-30 20:18:43,071 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=40.8 pTM=0.231
# 2023-06-30 20:19:02,018 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=46.3 pTM=0.304 tol=12
# 2023-06-30 20:19:20,958 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=46.2 pTM=0.285 tol=7.58
# 2023-06-30 20:19:39,907 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=51.5 pTM=0.317 tol=6.28
# 2023-06-30 20:19:39,908 alphafold2_multimer_v3_model_1_seed_000 took 75.8s (3 recycles)
# 2023-06-30 20:19:40,051 reranking models by 'plddt' metric
# 2023-06-30 20:19:40,052 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=51.5 pTM=0.317
# 2023-06-30 20:19:41,244 Query 17/102: hCLIC1Dimer_016 (length 241)
# 2023-06-30 20:20:00,178 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=45.7 pTM=0.302
# 2023-06-30 20:20:19,114 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=51.2 pTM=0.414 tol=7.73
# 2023-06-30 20:20:38,063 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=58.8 pTM=0.523 tol=4
# 2023-06-30 20:20:56,966 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=58.3 pTM=0.517 tol=1.22
# 2023-06-30 20:20:56,967 alphafold2_multimer_v3_model_1_seed_000 took 75.7s (3 recycles)
# 2023-06-30 20:20:57,046 reranking models by 'plddt' metric
# 2023-06-30 20:20:57,046 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=58.3 pTM=0.517
# 2023-06-30 20:20:58,141 Query 18/102: hCLIC1Dimer_017 (length 241)
# 2023-06-30 20:21:17,042 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=44.3 pTM=0.295
# 2023-06-30 20:21:35,943 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=42.6 pTM=0.303 tol=9.12
# 2023-06-30 20:21:54,861 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=43.4 pTM=0.279 tol=5.97
# 2023-06-30 20:22:13,750 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=46.8 pTM=0.301 tol=3.79
# 2023-06-30 20:22:13,752 alphafold2_multimer_v3_model_1_seed_000 took 75.6s (3 recycles)
# 2023-06-30 20:22:13,843 reranking models by 'plddt' metric
# 2023-06-30 20:22:13,843 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=46.8 pTM=0.301
# 2023-06-30 20:22:14,956 Query 19/102: hCLIC1Dimer_018 (length 241)
# 2023-06-30 20:22:33,852 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=43.8 pTM=0.303
# 2023-06-30 20:22:52,750 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=43.6 pTM=0.255 tol=3.53
# 2023-06-30 20:23:11,653 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=42.9 pTM=0.251 tol=3.03
# 2023-06-30 20:23:30,548 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=43.3 pTM=0.257 tol=2.73
# 2023-06-30 20:23:30,550 alphafold2_multimer_v3_model_1_seed_000 took 75.6s (3 recycles)
# 2023-06-30 20:23:30,691 reranking models by 'plddt' metric
# 2023-06-30 20:23:30,691 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=43.3 pTM=0.257
# 2023-06-30 20:23:32,707 Query 20/102: hCLIC1Dimer_019 (length 241)
# 2023-06-30 20:23:51,622 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=38.1 pTM=0.21
# 2023-06-30 20:24:10,435 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=39.9 pTM=0.212 tol=6.39
# 2023-06-30 20:24:29,264 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=38.6 pTM=0.195 tol=4.17
# 2023-06-30 20:24:48,106 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=39.5 pTM=0.2 tol=2.62
# 2023-06-30 20:24:48,108 alphafold2_multimer_v3_model_1_seed_000 took 75.4s (3 recycles)
# 2023-06-30 20:24:48,193 reranking models by 'plddt' metric
# 2023-06-30 20:24:48,194 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=39.5 pTM=0.2
# 2023-06-30 20:24:49,286 Query 21/102: hCLIC1Dimer_020 (length 241)
# 2023-06-30 20:25:08,107 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=40.7 pTM=0.235
# 2023-06-30 20:25:27,016 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=47.7 pTM=0.283 tol=6.36
# 2023-06-30 20:25:45,898 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=53.9 pTM=0.356 tol=6.83
# 2023-06-30 20:26:04,761 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=56.8 pTM=0.381 tol=7.27
# 2023-06-30 20:26:04,762 alphafold2_multimer_v3_model_1_seed_000 took 75.5s (3 recycles)
# 2023-06-30 20:26:04,842 reranking models by 'plddt' metric
# 2023-06-30 20:26:04,843 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=56.8 pTM=0.381
# 2023-06-30 20:26:05,928 Query 22/102: hCLIC1Dimer_021 (length 241)
# 2023-06-30 20:26:24,956 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=38.7 pTM=0.238
# 2023-06-30 20:26:43,979 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=44.2 pTM=0.305 tol=6.61
# 2023-06-30 20:27:03,024 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=50 pTM=0.406 tol=9.65
# 2023-06-30 20:27:22,068 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=51.8 pTM=0.411 tol=2.38
# 2023-06-30 20:27:22,070 alphafold2_multimer_v3_model_1_seed_000 took 76.1s (3 recycles)
# 2023-06-30 20:27:22,223 reranking models by 'plddt' metric
# 2023-06-30 20:27:22,224 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=51.8 pTM=0.411
# 2023-06-30 20:27:23,823 Query 23/102: hCLIC1Dimer_022 (length 241)
# 2023-06-30 20:27:42,729 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=37.1 pTM=0.21
# 2023-06-30 20:28:01,590 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=37.8 pTM=0.203 tol=5.38
# 2023-06-30 20:28:20,528 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=40.3 pTM=0.201 tol=4.01
# 2023-06-30 20:28:39,428 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=40.9 pTM=0.205 tol=1.89
# 2023-06-30 20:28:39,429 alphafold2_multimer_v3_model_1_seed_000 took 75.6s (3 recycles)
# 2023-06-30 20:28:39,506 reranking models by 'plddt' metric
# 2023-06-30 20:28:39,506 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=40.9 pTM=0.205
# 2023-06-30 20:28:40,599 Query 24/102: hCLIC1Dimer_023 (length 241)
# 2023-06-30 20:28:59,495 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=49.8 pTM=0.359
# 2023-06-30 20:29:18,403 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=55.2 pTM=0.381 tol=4.11
# 2023-06-30 20:29:37,379 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=57.3 pTM=0.396 tol=3.98
# 2023-06-30 20:29:56,356 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=58.2 pTM=0.397 tol=3.6
# 2023-06-30 20:29:56,359 alphafold2_multimer_v3_model_1_seed_000 took 75.8s (3 recycles)
# 2023-06-30 20:29:56,522 reranking models by 'plddt' metric
# 2023-06-30 20:29:56,523 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=58.2 pTM=0.397
# 2023-06-30 20:29:58,214 Query 25/102: hCLIC1Dimer_024 (length 241)
# 2023-06-30 20:30:17,228 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=41.7 pTM=0.255
# 2023-06-30 20:30:36,140 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=43.5 pTM=0.359 tol=11.6
# 2023-06-30 20:30:55,033 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=49.5 pTM=0.364 tol=8.66
# 2023-06-30 20:31:13,909 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=58.3 pTM=0.487 tol=6.94
# 2023-06-30 20:31:13,911 alphafold2_multimer_v3_model_1_seed_000 took 75.7s (3 recycles)
# 2023-06-30 20:31:13,991 reranking models by 'plddt' metric
# 2023-06-30 20:31:13,992 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=58.3 pTM=0.487
# 2023-06-30 20:31:15,096 Query 26/102: hCLIC1Dimer_025 (length 241)
# 2023-06-30 20:31:33,939 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=48.1 pTM=0.299
# 2023-06-30 20:31:52,789 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=47.7 pTM=0.26 tol=7.09
# 2023-06-30 20:32:11,645 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=48.6 pTM=0.292 tol=13
# 2023-06-30 20:32:30,486 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=49 pTM=0.285 tol=1.19
# 2023-06-30 20:32:30,490 alphafold2_multimer_v3_model_1_seed_000 took 75.4s (3 recycles)
# 2023-06-30 20:32:30,568 reranking models by 'plddt' metric
# 2023-06-30 20:32:30,568 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=49 pTM=0.285
# 2023-06-30 20:32:31,656 Query 27/102: hCLIC1Dimer_026 (length 241)
# 2023-06-30 20:32:50,705 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=79.4 pTM=0.693
# 2023-06-30 20:33:09,745 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=82.8 pTM=0.753 tol=1.37
# 2023-06-30 20:33:28,782 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=83.5 pTM=0.765 tol=1.46
# 2023-06-30 20:33:47,821 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=84.8 pTM=0.78 tol=0.841
# 2023-06-30 20:33:47,830 alphafold2_multimer_v3_model_1_seed_000 took 76.2s (3 recycles)
# 2023-06-30 20:33:48,044 reranking models by 'plddt' metric
# 2023-06-30 20:33:48,045 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=84.8 pTM=0.78
# 2023-06-30 20:33:50,129 Query 28/102: hCLIC1Dimer_027 (length 241)
# 2023-06-30 20:34:09,160 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=72.4 pTM=0.6
# 2023-06-30 20:34:28,109 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=77.4 pTM=0.583 tol=1.2
# 2023-06-30 20:34:47,092 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=82.4 pTM=0.745 tol=4.74
# 2023-06-30 20:35:06,055 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=83.7 pTM=0.757 tol=1.27
# 2023-06-30 20:35:06,056 alphafold2_multimer_v3_model_1_seed_000 took 75.9s (3 recycles)
# 2023-06-30 20:35:06,136 reranking models by 'plddt' metric
# 2023-06-30 20:35:06,137 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=83.7 pTM=0.757
# 2023-06-30 20:35:07,252 Query 29/102: hCLIC1Dimer_028 (length 241)
# 2023-06-30 20:35:26,076 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=51.1 pTM=0.332
# 2023-06-30 20:35:44,931 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=55.1 pTM=0.379 tol=4.82
# 2023-06-30 20:36:03,855 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=69.6 pTM=0.497 tol=6.27
# 2023-06-30 20:36:22,781 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=72.1 pTM=0.52 tol=6.59
# 2023-06-30 20:36:22,783 alphafold2_multimer_v3_model_1_seed_000 took 75.5s (3 recycles)
# 2023-06-30 20:36:22,942 reranking models by 'plddt' metric
# 2023-06-30 20:36:22,943 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=72.1 pTM=0.52
# 2023-06-30 20:36:24,626 Query 30/102: hCLIC1Dimer_029 (length 241)
# 2023-06-30 20:36:43,641 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=42.4 pTM=0.298
# 2023-06-30 20:37:02,520 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=40.3 pTM=0.287 tol=8.45
# 2023-06-30 20:37:21,418 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=43.9 pTM=0.273 tol=7.57
# 2023-06-30 20:37:40,319 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=46.3 pTM=0.281 tol=1.94
# 2023-06-30 20:37:40,320 alphafold2_multimer_v3_model_1_seed_000 took 75.7s (3 recycles)
# 2023-06-30 20:37:40,400 reranking models by 'plddt' metric
# 2023-06-30 20:37:40,401 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=46.3 pTM=0.281
# 2023-06-30 20:37:41,826 Query 31/102: hCLIC1Dimer_030 (length 241)
# 2023-06-30 20:38:00,740 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=54 pTM=0.406
# 2023-06-30 20:38:19,650 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=62.7 pTM=0.523 tol=4.87
# 2023-06-30 20:38:38,579 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=69.3 pTM=0.522 tol=2.29
# 2023-06-30 20:38:57,584 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=69.9 pTM=0.527 tol=2.43
# 2023-06-30 20:38:57,585 alphafold2_multimer_v3_model_1_seed_000 took 75.8s (3 recycles)
# 2023-06-30 20:38:57,738 reranking models by 'plddt' metric
# 2023-06-30 20:38:57,739 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=69.9 pTM=0.527
# 2023-06-30 20:38:59,413 Query 32/102: hCLIC1Dimer_031 (length 241)
# 2023-06-30 20:39:18,383 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=43.2 pTM=0.276
# 2023-06-30 20:39:37,290 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=52.8 pTM=0.332 tol=9.82
# 2023-06-30 20:39:56,230 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=55 pTM=0.348 tol=2.02
# 2023-06-30 20:40:15,158 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=57.2 pTM=0.387 tol=1.76
# 2023-06-30 20:40:15,160 alphafold2_multimer_v3_model_1_seed_000 took 75.7s (3 recycles)
# 2023-06-30 20:40:15,298 reranking models by 'plddt' metric
# 2023-06-30 20:40:15,298 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=57.2 pTM=0.387
# 2023-06-30 20:40:17,050 Query 33/102: hCLIC1Dimer_032 (length 241)
# 2023-06-30 20:40:36,008 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=53.5 pTM=0.339
# 2023-06-30 20:40:54,870 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=56.8 pTM=0.42 tol=9.77
# 2023-06-30 20:41:13,758 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=71.9 pTM=0.481 tol=7.26
# 2023-06-30 20:41:32,637 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=75.4 pTM=0.534 tol=6.09
# 2023-06-30 20:41:32,639 alphafold2_multimer_v3_model_1_seed_000 took 75.6s (3 recycles)
# 2023-06-30 20:41:32,715 reranking models by 'plddt' metric
# 2023-06-30 20:41:32,716 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=75.4 pTM=0.534
# 2023-06-30 20:41:33,791 Query 34/102: hCLIC1Dimer_033 (length 241)
# 2023-06-30 20:41:52,628 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=45 pTM=0.305
# 2023-06-30 20:42:11,475 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=55.1 pTM=0.374 tol=8.38
# 2023-06-30 20:42:30,359 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=55.2 pTM=0.375 tol=3.63
# 2023-06-30 20:42:49,270 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=58.3 pTM=0.379 tol=3.33
# 2023-06-30 20:42:49,273 alphafold2_multimer_v3_model_1_seed_000 took 75.5s (3 recycles)
# 2023-06-30 20:42:49,432 reranking models by 'plddt' metric
# 2023-06-30 20:42:49,433 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=58.3 pTM=0.379
# 2023-06-30 20:42:51,084 Query 35/102: hCLIC1Dimer_034 (length 241)
# 2023-06-30 20:43:10,067 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=47.7 pTM=0.3
# 2023-06-30 20:43:28,965 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=44.2 pTM=0.25 tol=6.51
# 2023-06-30 20:43:47,891 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=41.3 pTM=0.223 tol=8.01
# 2023-06-30 20:44:06,779 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=43 pTM=0.243 tol=9.84
# 2023-06-30 20:44:06,780 alphafold2_multimer_v3_model_1_seed_000 took 75.7s (3 recycles)
# 2023-06-30 20:44:06,858 reranking models by 'plddt' metric
# 2023-06-30 20:44:06,859 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=43 pTM=0.243
# 2023-06-30 20:44:07,950 Query 36/102: hCLIC1Dimer_035 (length 241)
# 2023-06-30 20:44:26,826 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=46 pTM=0.355
# 2023-06-30 20:44:45,769 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=47.2 pTM=0.318 tol=4.08
# 2023-06-30 20:45:04,692 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=53.2 pTM=0.32 tol=4.32
# 2023-06-30 20:45:23,596 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=64.9 pTM=0.475 tol=6.33
# 2023-06-30 20:45:23,598 alphafold2_multimer_v3_model_1_seed_000 took 75.6s (3 recycles)
# 2023-06-30 20:45:23,673 reranking models by 'plddt' metric
# 2023-06-30 20:45:23,673 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=64.9 pTM=0.475
# 2023-06-30 20:45:24,747 Query 37/102: hCLIC1Dimer_036 (length 241)
# 2023-06-30 20:45:43,703 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=43.8 pTM=0.309
# 2023-06-30 20:46:02,658 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=43.8 pTM=0.28 tol=9.48
# 2023-06-30 20:46:21,643 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=44.7 pTM=0.273 tol=6.13
# 2023-06-30 20:46:40,621 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=46.6 pTM=0.281 tol=4.82
# 2023-06-30 20:46:40,623 alphafold2_multimer_v3_model_1_seed_000 took 75.9s (3 recycles)
# 2023-06-30 20:46:40,772 reranking models by 'plddt' metric
# 2023-06-30 20:46:40,773 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=46.6 pTM=0.281
# 2023-06-30 20:46:42,523 Query 38/102: hCLIC1Dimer_037 (length 241)
# 2023-06-30 20:47:01,485 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=45.2 pTM=0.332
# 2023-06-30 20:47:20,392 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=54.2 pTM=0.385 tol=9.1
# 2023-06-30 20:47:39,290 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=57.4 pTM=0.404 tol=2.09
# 2023-06-30 20:47:58,166 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=59.6 pTM=0.433 tol=2.08
# 2023-06-30 20:47:58,167 alphafold2_multimer_v3_model_1_seed_000 took 75.6s (3 recycles)
# 2023-06-30 20:47:58,260 reranking models by 'plddt' metric
# 2023-06-30 20:47:58,260 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=59.6 pTM=0.433
# 2023-06-30 20:47:59,348 Query 39/102: hCLIC1Dimer_038 (length 241)
# 2023-06-30 20:48:18,228 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=37.3 pTM=0.204
# 2023-06-30 20:48:37,122 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=38 pTM=0.207 tol=9.45
# 2023-06-30 20:48:56,075 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=37.5 pTM=0.222 tol=3.97
# 2023-06-30 20:49:15,020 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=37.5 pTM=0.221 tol=2.8
# 2023-06-30 20:49:15,022 alphafold2_multimer_v3_model_1_seed_000 took 75.7s (3 recycles)
# 2023-06-30 20:49:15,184 reranking models by 'plddt' metric
# 2023-06-30 20:49:15,184 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=37.5 pTM=0.221
# 2023-06-30 20:49:16,846 Query 40/102: hCLIC1Dimer_039 (length 241)
# 2023-06-30 20:49:35,829 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=42.7 pTM=0.267
# 2023-06-30 20:49:54,821 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=49.6 pTM=0.314 tol=9.38
# 2023-06-30 20:50:14,145 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=58.7 pTM=0.434 tol=8.64
# 2023-06-30 20:50:33,503 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=63.2 pTM=0.517 tol=4.07
# 2023-06-30 20:50:33,505 alphafold2_multimer_v3_model_1_seed_000 took 76.7s (3 recycles)
# 2023-06-30 20:50:33,584 reranking models by 'plddt' metric
# 2023-06-30 20:50:33,585 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=63.2 pTM=0.517
# 2023-06-30 20:50:34,673 Query 41/102: hCLIC1Dimer_040 (length 241)
# 2023-06-30 20:50:53,916 alphafold2_multimer_v3_model_1_seed_000 recycle=0 pLDDT=42 pTM=0.27
# 2023-06-30 20:51:13,044 alphafold2_multimer_v3_model_1_seed_000 recycle=1 pLDDT=42.3 pTM=0.269 tol=5.91
# 2023-06-30 20:51:32,181 alphafold2_multimer_v3_model_1_seed_000 recycle=2 pLDDT=47.6 pTM=0.321 tol=6.55
# 2023-06-30 20:51:51,403 alphafold2_multimer_v3_model_1_seed_000 recycle=3 pLDDT=64 pTM=0.55 tol=4.56
# 2023-06-30 20:51:51,404 alphafold2_multimer_v3_model_1_seed_000 took 76.7s (3 recycles)
# 2023-06-30 20:51:51,567 reranking models by 'plddt' metric
# 2023-06-30 20:51:51,568 rank_001_alphafold2_multimer_v3_model_1_seed_000 pLDDT=64 pTM=0.55
# 2023-06-30 20:51:53,253 Query 42/102: hCLIC1Dimer_041 (length 241)

# %% [markdown]
# # Instructions <a name="Instructions"></a>
# **Quick start**
# 1. Upload your single fasta files to a folder in your Google Drive
# 2. Define path to the fold containing the fasta files (`input_dir`) define an outdir (`output_dir`)
# 3. Press "Runtime" -> "Run all".
#
# **Result zip file contents**
#
# At the end of the job a all results `jobname.result.zip` will be uploaded to your (`output_dir`) Google Drive. Each zip contains one protein.
#
# 1. PDB formatted structures sorted by avg. pIDDT. (unrelaxed and relaxed if `use_amber` is enabled).
# 2. Plots of the model quality.
# 3. Plots of the MSA coverage.
# 4. Parameter log file.
# 5. A3M formatted input MSA.
# 6. BibTeX file with citations for all used tools and databases.
#
#
# **Troubleshooting**
# * Check that the runtime type is set to GPU at "Runtime" -> "Change runtime type".
# * Try to restart the session "Runtime" -> "Factory reset runtime".
# * Check your input sequence.
#
# **Known issues**
# * Google Colab assigns different types of GPUs with varying amount of memory. Some might not have enough memory to predict the structure for a long sequence.
# * Google Colab assigns different types of GPUs with varying amount of memory. Some might not have enough memory to predict the structure for a long sequence.
# * Your browser can block the pop-up for downloading the result file. You can choose the `save_to_google_drive` option to upload to Google Drive instead or manually download the result file: Click on the little folder icon to the left, navigate to file: `jobname.result.zip`, right-click and select \"Download\" (see [screenshot](https://pbs.twimg.com/media/E6wRW2lWUAEOuoe?format=jpg&name=small)).
#
# **Limitations**
# * Computing resources: Our MMseqs2 API can handle ~20-50k requests per day.
# * MSAs: MMseqs2 is very precise and sensitive but might find less hits compared to HHblits/HMMer searched against BFD or Mgnify.
# * We recommend to additionally use the full [AlphaFold2 pipeline](https://github.com/deepmind/alphafold).
#
# **Description of the plots**
# *   **Number of sequences per position** - We want to see at least 30 sequences per position, for best performance, ideally 100 sequences.
# *   **Predicted lDDT per position** - model confidence (out of 100) at each position. The higher the better.
# *   **Predicted Alignment Error** - For homooligomers, this could be a useful metric to assess how confident the model is about the interface. The lower the better.
#
# **Bugs**
# - If you encounter any bugs, please report the issue to https://github.com/sokrypton/ColabFold/issues
#
# **License**
#
# The source code of ColabFold is licensed under [MIT](https://raw.githubusercontent.com/sokrypton/ColabFold/main/LICENSE). Additionally, this notebook uses AlphaFold2 source code and its parameters licensed under [Apache 2.0](https://raw.githubusercontent.com/deepmind/alphafold/main/LICENSE) and  [CC BY 4.0](https://creativecommons.org/licenses/by-sa/4.0/) respectively. Read more about the AlphaFold license [here](https://github.com/deepmind/alphafold).
#
# **Acknowledgments**
# - We thank the AlphaFold team for developing an excellent model and open sourcing the software.
#
# - Do-Yoon Kim for creating the ColabFold logo.
#
# - A colab by Sergey Ovchinnikov ([@sokrypton](https://twitter.com/sokrypton)), Milot Mirdita ([@milot_mirdita](https://twitter.com/milot_mirdita)) and Martin Steinegger ([@thesteinegger](https://twitter.com/thesteinegger)).
